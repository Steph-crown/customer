# %%
import pandas as pd

# %%
customer = pd.read_csv(r"C:\Users\USER\Downloads\Customer List.csv")

# %%
customer
# Out:
#      Customer ID  Gender  Age  Salary  Purchased
# 0              1    Male   19   19000          0
# 1              2    Male   35   20000          0
# 2              3  Female   26   43000          0
# 3              4  Female   27   57000          0
# 4              5    Male   19   76000          0
# ..           ...     ...  ...     ...        ...
# 395          396  Female   46   41000          1
# 396          397    Male   51   23000          1
# 397          398  Female   50   20000          1
# 398          399    Male   36   33000          0
# 399          400  Female   49   36000          1
#
# [400 rows x 5 columns]

# %%
customer.head(100)
# Out:
#     Customer ID  Gender  Age  Salary  Purchased
# 0             1    Male   19   19000          0
# 1             2    Male   35   20000          0
# 2             3  Female   26   43000          0
# 3             4  Female   27   57000          0
# 4             5    Male   19   76000          0
# ..          ...     ...  ...     ...        ...
# 95           96  Female   35   44000          0
# 96           97  Female   35   25000          0
# 97           98    Male   28  123000          1
# 98           99    Male   35   73000          0
# 99          100  Female   28   37000          0
#
# [100 rows x 5 columns]

# %%
customer.tail(5)
# Out:
#      Customer ID  Gender  Age  Salary  Purchased
# 395          396  Female   46   41000          1
# 396          397    Male   51   23000          1
# 397          398  Female   50   20000          1
# 398          399    Male   36   33000          0
# 399          400  Female   49   36000          1

# %%
customer_copy = customer.copy()

# %%
customer_copy
# Out:
#      Customer ID  Gender  Age  Salary  Purchased
# 0              1    Male   19   19000          0
# 1              2    Male   35   20000          0
# 2              3  Female   26   43000          0
# 3              4  Female   27   57000          0
# 4              5    Male   19   76000          0
# ..           ...     ...  ...     ...        ...
# 395          396  Female   46   41000          1
# 396          397    Male   51   23000          1
# 397          398  Female   50   20000          1
# 398          399    Male   36   33000          0
# 399          400  Female   49   36000          1
#
# [400 rows x 5 columns]

# %%
customer.shape
# Out:
# (400, 5)

# %%
customer.drop(["Customer ID"], axis="columns")
# Out:
#      Gender  Age  Salary  Purchased
# 0      Male   19   19000          0
# 1      Male   35   20000          0
# 2    Female   26   43000          0
# 3    Female   27   57000          0
# 4      Male   19   76000          0
# ..      ...  ...     ...        ...
# 395  Female   46   41000          1
# 396    Male   51   23000          1
# 397  Female   50   20000          1
# 398    Male   36   33000          0
# 399  Female   49   36000          1
#
# [400 rows x 4 columns]

# %%
# The features of this data set are "Gender", "Age", "Salary"

# %%
# The label is "Purchased"
